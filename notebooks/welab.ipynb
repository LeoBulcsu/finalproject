# %%
import pandas as pd
import numpy as np

# %%
lenses = pd.read_json('../src/welabscraper/welabscraper/welab_lenses.json')

# %%
lenses
# Out:
#     CATEGORY   BRAND       TYPE  \
# 0     LENSES   leitz  lpl-prime
# 1     LENSES  tokina   pl-prime
# 2     LENSES  tokina   pl-prime
# 3     LENSES  tokina   pl-prime
# 4     LENSES  tokina   pl-prime
# ..       ...     ...        ...
# 457   LENSES   canon    pl-zoom
# 458   LENSES   zeiss    pl-zoom
# 459   LENSES   zeiss    pl-zoom
# 460   LENSES   zeiss    pl-zoom
# 461   LENSES   zeiss    pl-zoom
#
#                                                NAME PRICE a day RENTAL  \
# 0    SET LENTES LEITZ ELSIE (18,25,35,50,75,100 mm)         850  WELAB
# 1      SET x5 LENTES TOKINA VISTA 18,25,35,50,85 mm         225  WELAB
# 2                    TOKINA VISTA CINEMA PRIME 18mm          50  WELAB
# 3                    TOKINA VISTA CINEMA PRIME 25mm          50  WELAB
# 4                    TOKINA VISTA CINEMA PRIME 35mm          50  WELAB
# ..                                              ...         ...    ...
# 457                  CANON ZOOM CINE-SERVO 17-120mm         150  WELAB
# ...

# %%
len(lenses[lenses['TYPE']=='anamorficas'])
# Out:
# 31

# %%
lights = pd.read_json('../data/welab_lights.json')

# %%
lights
# Out:
#     CATEGORY     SubCatgory                    TYPE  \
# 0   LIGHTING     bastidores      telas-y-bastidores
# 1   LIGHTING     bastidores      telas-y-bastidores
# 2   LIGHTING     bastidores      telas-y-bastidores
# 3   LIGHTING       sujecion  accesorios-iluminacion
# 4   LIGHTING       sujecion  accesorios-iluminacion
# 5   LIGHTING       sujecion  accesorios-iluminacion
# 6   LIGHTING          telas      telas-y-bastidores
# 7   LIGHTING          telas      telas-y-bastidores
# 8   LIGHTING      flexibles                     led
# 9   LIGHTING      flexibles                     led
# 10  LIGHTING      bombillas                     led
# 11  LIGHTING     especiales                     led
# 12  LIGHTING     especiales                     led
# 13  LIGHTING      antorchas                     led
# 14  LIGHTING      antorchas                     led
# 15  LIGHTING      antorchas                     led
# 16  LIGHTING      antorchas                     led
# ...
